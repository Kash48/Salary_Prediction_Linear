# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Scatter plot

# %% [markdown]
# 1.Scatter Plots:
#
# These are used to infer the relationship between 2 variables.
#
# In statistics, the graphs are used very frequently in order to understand and interpret large number of data points. There are various graphs available in statistics, like - bar graph, histogram, pie chart, frequency polygon, cumulative frequency curve, stem and leaf plot, scatter plot etc. Each graph has its own importance. In this section, we shall learn about scatter plots.
#
# Scatter plots show the relationship between two variables by displaying data points on a two-dimensional graph. In this type of graph, there are two separate variables(BI-VARIATE). The variable that might be measured, known as an explanatory variable, it is plotted on the X axis. Another variable, termed as a reply or response variable is plotted on the Y axis. Scatter plots are especially helpful when there is a large number of a data points and provides relationship between two variables. One gets an overall information about data with the help of scatter plot. It is also useful in explaining the correlation between two variables. In general, it seems as a bunch of points scattered over a range. It is useful in finding the range and spread of the data. A simple scatter plot looks as shown in the figure given below.
#
#
# Scatter Plot Definition
# A scatter plot or scatter plot graph is a graph which is drawn in Cartesian coordinate to visually represent the values for two variables for a set of data. It is a graphical representation that shows how one variable is affected by the other. The data is presented in the form of collection of points, each of which has one value of a variable positioned on the horizontal or x-axis, also called explanatory variable and the value of the other variable positioned on the vertical or y-axis, also called response variable. So it can be defined as a way of showing the relationship between any two variable by using data point on a two dimensional graph.
#
# Use of Scatter Plot
# The importance of scatter plot is that it helps to see how two comparable data sets will agree with each other. In such condition we use the identity line as a reference to plotting the rest of the points. The more the two data come in arrangement, the more the scatter tend to be near the vicinity of the identity line, if the two data sets are numerically same, the scatter and the identity line becomes exactly same.
# Each data point denoted by a small circle in the graph. If the values on x-axis to increase as of y axis increase. This causes the formation of a scatter plot in which the points cluster together around an imaginary line which is moving from the lower left side of the graph to the upper right side. Hence a positive relationship can be seen between these two variables.
#
# Inferences:When there is a large number of data points, scatter plot comes very handy. They give emphases on the following factors:
#
# Strength between the variable
# Shape formed
# Direction of association
# Outliers
# Range
# Dispersion
#
# 2.	Inter and Extra polation:
# Interpolation: It is the prediction of values within the given range of data. See Graph 1
# Extrapolation: Prediction of data outside the given range of data, it can be compared to the forecasting or prediction method. See Graph 2
#
# 3.	Python scatter plot code:
# The data points are less and the conclusion can not be drawn. However still it gives a sense of the data direction.
# Matplotlib is used for plotting the scatter plot, plt.scatter is used for plotting the scatter plot.
# Refer notes for scatter plot by Seaborn library :)
#
# Module: Module is a file which contains various Python functions and also global variables. It is simply just .py extension file which has python executable code. This is similar to import amit_func as am.
#
#  Library/Package: On the other hand , Package is nothing but a collection of modules. It must contains __init__.py file to let the python interpreter know this is not just simple directory but a collection of modules or package. Basically you d	on’t have to write anything in __init__.py file but must be there in the module directory.
#
# import matplotlib.pyplot as plt
# plt.scatter(x,y,c="Red")
#
# matplotlib is a library or a package
# pyplot is a module(collection of functions)
# scatter is a function that takes 3 arguments and it is available in the module pyplot

# %%
#The below code shows how to plot between x and y and create a scatter plot for admit data
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading the csv to a dataframe
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/admit.csv')
#Reading X and Y to the different series
age=df['Age']
height=df['Height']

# %%
# Plottting scatter using the scatter function from matplotlib
plt.scatter(age,height,c="Red")
plt.title('Scatter plot age and height')
plt.xlabel('Age in years')
plt.ylabel('Height in cms')
# This helps to show the current graph, if we dont use it, graph still comes with the last command in output as well.
plt.show()

# %% [markdown]
# # Scatter plot 2

# %%
# The below code shows how to plot between x and y and create a scatter plot for salary data
#Reading the csv to a dataframe
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary.csv')

# %%
#Reading X and Y to the different series
year=df['YearsExperience'].values
sal=df['Salary'].values
# Plottting scatter using the scatter function from matplotlib
plt.scatter(year, sal, c="green")
plt.title('Scatter plot of years and Salary')
plt.xlabel('Exp in years')
plt.ylabel('Sal in $')
plt.show()

# %% [markdown]
# # Seaborn scatter plot

# %%
# Regression plot using Seaborn library, regplot helps in creating a beautiful graph in 2 dimenson
# The Regression line that comes by default can be avoided by using fit_reg=False
import seaborn as sb
import pandas as pd
df =pd.read_csv('admit.csv')

# use the function regplot to make a scatterplot with x and y series, fit_reg=False would not give Identity line
sb.regplot(x=df["Age"], y=df["Height"] , fit_reg=False)

# %% [markdown]
# # Seaboran Scatter plot with Reg line

# %%
# Regression plot using Seaborn library, regplot helps in creating a beautiful graph
# By default it creates the Regression line
import seaborn as sb
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/admit.csv')

# use the function regplot to make a scatterplot
sb.regplot(x=df["Age"], y=df["Height"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Pair plot

# %%
# The below code shows how to plot between all the numeric variables, just like a matrix or a grid
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/admit.csv')
df=df[['Age','Height','Weight','Fee','Date']]

#Lets look at the scatter plot using the seaborn module, this gives a pair between all variables, scroll till bottom :)
# This is a cross plot, focus on the diagonal,its in a matrix form
# only numeric variables are being used to plot, we would see later what would happen if we push the entire dataframe
sb.pairplot(df)

# %% [markdown]
# # Pair plot Categorical Var

# %%
# The below code shows how to plot between all the numeric variables, just like a matrix or a grid
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/admit.csv')

# What would happen if I include a categorical variable, it would basically ignore them and plot only numerical
#Lets look at the scatter plot using the seaborn module, this gives a pair between all variables, scroll till bottom :)
# This is a cross plot, focus on the diagonal,its in a matrix form
sb.pairplot(df)

# %% [markdown]
# Regression: Derived from the word "regress", in 1877 Sir Francis Galton, studied how the height of children born to tall parents move or regress towards the mean height of population :) Regression was then used as a general process of predicting one variable from another, I bet you did not know this :)
#
# Regression help you to predict the realtionship of association and not the cause and effect.
#
# Independent var: Variable(s) that are known/available are called as Independent variable., also known as predictor , explanatory variable. Simply X
# Dependent var: The varaible that we are trying to predict are known as dependent variable, also known as response, outcome variable. Simply Y
#
# Simple linear regression is a statistical method that allows us to summarize and study relationships between two continuous (quantitative) variables:
# One variable, denoted x, is regarded as the predictor, explanatory, or independent variable.
# The other variable, denoted y, is regarded as the response, outcome, or dependent variable.
# Because the other terms are used less frequently , we'll use the "predictor" and "response" terms to refer to the variables encountered. The other terms are mentioned only to make you aware of them, do not be confused should you encounter them.
# Simple linear regression gets its adjective "simple," because it concerns the study of only one predictor variable. In contrast, multiple linear regression,gets its adjective "multiple," because it concerns the study of two or more predictor variables.
#
# Line of Best fit is the line that is principally closest to all the Data Points. This is also known as the "Trend Line"

# %% [markdown]
# ### Regression Line/Line of Best Fit:

# %% [markdown]
# What is the definition of regression line? Regression lines are very useful for forecasting or prediction. The purpose of the line is to describe the interrelation of a dependent variable (Y variable) with one or many independent variables (X variable). By using the equation obtained from the regression line an analyst can forecast future behaviors of the dependent variable by inputting different values for the independent ones. Regression lines are widely used in the financial sector and business in general.
#
# Regression line help in Extrapolation.
#
# Financial analysts employ linear regressions to forecast stock prices, commodity prices and to perform valuations for many different securities. On the other hand, companies use regression for the purpose of forecasting sales, inventories and many other variables that are crucial for strategy and planning. The regression line formula is mentioned below:
#
# Y = a + bX or mx+c or b0+b1x1 etc
#
# Y=Dependent Var
#
# X=Independent var
#
# a=Y intercept, the point where line touches Y axis and X is 0
#
# b= Slope of the line, mathematically defines as y2-y1/x2-x1
#
# Slope is defined as the measure of change in y with respect to x, how does the y changes with each unit change in x.

# %% [markdown]
# Line1: Lets  Consider line1 with deviation or errors as  2,2, and -4
#
# Line2: Lets  Consider line2 with deviation or errors as  6,-2 and -4.
#
# Method 1: Lets simply sum the deviation for Line1 and Line2, it would come as 0 as positive and negative values cancel each other.
#
# Conclusion: we can not add the true values of devaition for identifying the best fit line.
#
# Method 2:  Lets take absolute sum the deviation for Line1 and Line2, it would come as 8 and 12 for Line1 and Line2 and this would seem to be a good choice for understanding the best fit line.
#
# Conclusion: The absolute sum is better than the simple addition of the deviations from the line.
#
#
# ********let's consider more situations **********************;
#
# Line1: Lets  Consider line1 with deviation or error as  0,0 and 4
#
# Line2: Lets  Consider line2 with deviation or error as  -1,-1 and 3.
#
# Method 1: Lets take absolute sum the deviation for Line1 and Line2, it would come as 4 and 5 for Line1 and Line2, what is your conclusion.
# Method 2:  Lets take squared deviations and add them for both lines, it comes as 16 and 11, what is your conclusion.
#
# Conclusion: The squared sum  of errors is better than the absolute addition of the deviations for the line.
#
# This forms the basics of Least squares method or Ordinary Least Squares (OLS) and is used for finding the best fit line.
#
# Advantages of Least Squares:
#
# 1. Help in avoiding the cancelling affect of +ve and -ve deviations.
# 2. Any value that have a huge deviation is penalized to a good extent, as we are squaring the deviation or error.

# %% [markdown]
# Least-Squares Regression Method or Ordinary Least Squares
#
# The least squares method is an important statistical technique that is used to find a regression line or a best-fit line for given model. This method is represented by an equation with certain parameters. The method of least squares is abundantly used in estimation and regression. In regression analysis, this method is said to be a standard approach for the approximation of sets of equations having more equations than the number of unknowns.
#
# The method of least squares actually defines the solution for the minimization of sum of squares of deviations or the errors in the result of each equation.
#
# The least squares method is mostly applied in data fitting. The best fit result is supposed to minimize the sum of squared errors or residuals which are said to be the differences between observed or experimental value and corresponding fitted value given in the model. The are two basic categories of the least squares problems - ordinary or linear least squares and nonlinear least squares. These depend upon linearity or nonlinearity of the residuals. The linear problems are mostly seen in regression analysis in statistics. On the other hand, the non-linear problems is generally use iterative method of refinement in which the model is approximated to the linear one with each iteration.
#
# y = a + bx

# %% [markdown]
# Line of Best Fit (Least Square Method)
# A line of best fit is a straight line that is the best approximation of the given set of data and the cumulative sum of squared deviations is minimum.
# It is used to study the nature of the relation between two variables. (We're only considering the two-dimensional case, here.)
# A line of best fit can be roughly determined using an eyeball method by drawing a straight line on a scatter plot so that the number of points above the line and below the line is about equal (and the line passes through as many points as possible).
# A more accurate way of finding the line of best fit is the least square method

# %% [markdown]
# Standard error of estimate:
# Similar to standard deviation/sigma we are trying to understand the  accuracy  or reliability of best fit line.  To measure  the reliability  of the  estimating equation we have standard error of estimate.
# It measures the variability or scatter around the regression line.
# For calculating the error of estimate we divide by N-2 as we have lost 2 degrees of freedom, as we are calculating 2 parameter, mean of x from  series 1 and mean of y from series 2
# se=(√summation(y-yhat)square/n-2)) also called as RMSE Root mean square error or RMSD Root mean square deviation
#
# The Numerator is nothing but SSE: Sum of squared errors
# The denominator is the Degrees of Freedom
#
# Prediction Intervals:
#
# 1. within 2Se the data is 68 %
#
# y=a+bx+1se and y=a+bx-1se
#
# 2. within 4Se the data is 95.5%
#
# y=a+bx+2se and y=a+bx-2se
#
# 3. within 6 Se the data is 99.97%
#
# y=a+bx+3se and y=a+bx-3se

# %% [markdown]
# Coefficient of Determination or ( R-squared):
#
# What is R-squared and what does it do?
#
# R-squared is a statistical measure that’s used to assess the goodness of fit of our regression model.
# In R-squared we have a baseline model which is the worst model. This baseline model doesn’t make use of any independent variables to predict the value of dependent variable Y. Instead it uses the mean of the observed responses of dependent variable Y and always predicts this mean as the value of Y.
# Any regression model that we fit is compared to this baseline model to understand it’s goodness of fit. This baseline model is the control model by default.
#
# In other words R-squared simply explains how good is your model when compared to the baseline model(model that follows mean or avearage).
#
# Baseline model: Take the avearge of Y variable, lets say an average salaray and there would be single value and a flat horizontal line.
#
# Fitted model: It makes the use of X to predict Y and follow the best fit line and least sum of squared errors.
#
# SSE: Sum Squared Error, It is the unexplained deviation wrt regreession line.
#
# SST: Sum Squared Total, It is the total observed deviation.
#
# SSR: Sum Squared Regression, This is the explained deviation by the regression line.
#
# R2=SSR/SST or
#
# R2=1-SSE/SST ( Stick to this, there are many variations of this equation)
#
# Worst model R-Squared=1-1=0
#
# Best model R-Squared=1-0=1
#
# How to interpret R-squared?
#
# If R-squared=0.93 then it means 93% variations in dependent variable Y is explained by the independent variable X present in our model. We can say that the goodness of fit is 93% and it is a good model.
#
# The Thumb rule is R2 of 0.6 is considered decent. This still depends on the problem at hand and the data
# we are handling.
#
# Adjusted R2 is another parameter that should be looked upon very carefully.

# %% [markdown]
# How is R-squared different from Adjusted R-squared?
#
# R-squared tells you how well your model fits the data points whereas Adjusted R-squared tells you how important is a particular feature/variable to your model.
#
# Always check for R square and adjusted R square.

# %% [markdown]
# Coefficient of Correlation: It is the square root of coefficientof determination or the R sqaure.
#
# Rsquare fluctuates between 0 and 1 and Coefficient of Correlation would vary between -1 and 1
#
# Coefficient of Correlation (R): It gives the direction and strength of assocoation between 2 variables. The value of this coefficient  fluctuates between -1 and +1.

# %% [markdown]
# What is Variance?
#
# In statistics, variance refers to the spread of a data set. It’s a measurement used to identify how far each number in the data set is from the mean.
# While performing market research, variance is particularly useful when calculating probabilities of future events. Variance is a great way to find all of the possible values and likelihoods that a random variable can take within a given range.
# A variance value of zero represents that all of the values within a data set are identical, while all variances that are not equal to zero will come in the form of positive numbers.
# The larger the variance, the more spread in the data set.
# A large variance means that the numbers in a set are far from the mean and each other. A small variance means that the numbers are closer together in value.
#
# How to Calculate Variance
# Variance is calculated by taking the differences between each number in a data set and the mean, squaring those differences to give them positive value, and dividing the sum of the resulting squares by the number of values in the set.
#
# An Advantage of Variance
#
# One of the primary advantages of variance is that it treats all deviations from the mean of the data set in the same way, regardless of direction.
# This ensures that the squared deviations cannot sum to zero, which would result in giving the appearance that there was no variability in the data set at all.
#
# A Disadvantage of Variance
#
# One of the most commonly discussed disadvantages of variance is that it gives added weight to numbers that are far from the mean, or outliers. Squaring these numbers can at times result in skewed interpretations of the data set as a whole.

# %% [markdown]
# What is Covariance?
#
# Covariance provides insight into how two variables are related to one another.
# More precisely, covariance refers to the measure of how two random variables in a data set will change together.
# A positive covariance means that the two variables at hand are positively related, and they move in the same direction.
# A negative covariance means that the variables are inversely related, or that they move in opposite directions.
#
# Are Covariance and Correlation The Same Thing?
#
# Simply put, no.
#
# While both covariance and correlation indicate whether variables are positively or inversely related to each other, they are not considered to be the same.
# This is because correlation also informs about the degree to which the variables tend to move together.
# Covariance is used to measure variables that have different units of measurement and is unit dependent. By leveraging covariance, researchers are able to determine whether units are increasing or decreasing, but they are unable to solidify the degree to which the variables are moving together due to the fact that covariance does not use one standardized unit of measurement.
# Correlation, on the other hand, standardizes the measure of interdependence between two variables and informs researchers as to how closely the two variables move together.

# %% [markdown]
# Correlation Coefficient
#
# The correlation coefficient is the term used to refer to the resulting correlation measurement. It will always maintain a value between plus one and negative one,-1 to +1.
# When the correlation coefficient is one, the variables under examination have a perfect positive correlation. In other words, when one moves, so does the other in the same direction, proportionally.
# If the correlation coefficient is less than one, but still greater than zero, it indicates a less than perfect positive correlation. The closer the correlation coefficient gets to one, the stronger the correlation between the two variables.
# When the correlation coefficient is zero, it means that there is no identifiable relationship between the variables. If one variable moves, it’s impossible to make predictions about the movement of the other variable.
# If the correlation coefficient is negative one, this means that the variables are perfectly negatively or inversely correlated. If one variable increases, the other will decrease at the same proportion. The variables will move in opposite directions from each other.
# If the correlation coefficient is greater than negative one, it indicates that there is an imperfect negative correlation. As the correlation approaches negative one, the correlation grows.
#
# Correlation and Co-variance both are used as a measure to check how two variables change with respect to each other.
#
# Covariance: measure of change of how two variables change with respect to each other.
# It is unit dependent.
#
# Difference in scale can output different co-variance.
#
# It varies from - infinity to infinity
#
# Example: Height vs weight(kg) and Height vs weight(lbs) will have different covariance values
#
# In formula E stands for the Expected value or simply put the mean. Mean is the Expected value.
#
#
# Correlation :
#
# unit measure of change between two variables change with respect to each other. ( Basically it’s normalized covariance value)
#
# It is unit independent.
#
# Difference in scale doesn’t affect the correlation value
#
# It varies from -1 to 1.
#
# Example: Height vs weight(kg) and Height vs weight(lbs) will have same correlation values

# %% [markdown]
# Below are the main assumptions/decisions of SLR(Simple Linear Regression)
#
# 1. The 2 variables X and Y need to be continous numeric, NOT categorical.
#
# 2. Data is free of Missing values, if missing values are there MVT need to be performed.
#
# 3. Data is free of outliers, if the  outliers are there take a business decision for removal.
#
# 4. Linear relationship between X and Y, use the scatter plot,covariance  and correlation for check.
#
# ***Below is a suggestion****
# 5. Depending on the case/business need, data should be split into TRAIN and TEST

# %% [markdown]
# # Business Sense

# %% [markdown]
# #The Historical Salary data is available for 30 employees, the salary is not structured as per the years of experience; however that is what the company have, they are looking for obtaining the below mentioned insights.
#
# Sought after Insights:
#
# 1. Analyze the data and see if there is a correlation in salary and the years of experience.
#
# 2. Try and build a Regression model that would help the HR to predict the salary of the person that has an experience outside of the available experience data.
#
# 3. Try and build a model that helps to predict the salary as per the market standard and at PAR.
#
# 4. If an employee demands an x amount of salary the HR should be in a position to say that the x amount is less or greater by y percentage and take an informed decision.

# %% [markdown]
# # Salary and the Experience predictions

# %% [markdown]
# ### Regression from Scratch

# %%
#Importing various modules required in the model creation and graphing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sb

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary.csv')
print (df.shape)
df.head()
# Out:
# (30, 2)
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
'''collecting X and Y data from the data frame to one dimension numpy array, 
look at the size in Variable explorer
In scratch code even if you go with the data series, it is fine, converting to array help in fast execution
and models do not go well with a dataframe
'''

X=df['YearsExperience'].values
Y=df['Salary'].values

#Arithmetic mean of x and y variables, using the mean function from numpy
mean_x=np.mean(X)
mean_y=np.mean(Y)

#To print the captured mean of x and y for clarity, look at console  or at variable explorer:)
print(round(mean_x,2),round(mean_y,2))
# Out:
# 5.31 76003.0

# %%
#Total number of values captured in  a array, basically the number of rows, this would help in loop iterations
n=len(X)

#calculating the linear regression coefficients,the slope(b) and the y Intercept(a)
numer=0;
denom=0

for i in range(n):
    numer+=(X[i]-mean_x) * (Y[i]-mean_y) #Covariance of X and Y, this is the numerator
    denom+=(X[i]-mean_x)**2 #Variance of X, this is the denominator

b=numer/denom #equation of calculating slope of best fit line using OLS  
a=mean_y-(b*mean_x) #equation of y intercept of best fit line using OLS

#print the coefficients of the best fit line
print("covariance", numer)
print("variance", denom)
print("Slope of best fit line",a)
print("Y intercept of best fit line",b)
# Out:
# covariance 2207082.8
# variance 233.55466666666663
# Slope of best fit line 25792.20019866869
# Y intercept of best fit line 9449.962321455077

# %%
#plotting regression line and the actual observed point using the seaborn module
sb.regplot(x=df["YearsExperience"], y=df["Salary"])

#Calculate the r square, for the goodness of fit, that helps in undersating how much the model explains the data points
#The R sqaure comes out to be .9569, this means 95.69% of the variation is explained by the model :)
sse=0 # Sum of squared errors(y-yhat)
sst=0 # Sumof squared Total(y-ybar)
rmse=0

for i in range(n):
    y_pred=a+b*X[i]
    sst+=(Y[i]-mean_y)**2
    sse+=(Y[i]-y_pred)**2
    rmse+=(((Y[i]-y_pred)**2)/n-2)
print("sst", sst)
print("sse", sse)
print("rmse",rmse)
print(rmse**0.5)
r2=1-(sse/sst)
print("R-Square",r2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# sst 21794977852.0
# sse 938128551.6684291
# rmse 31270891.722280968
# 5592.038243993058
# R-Square 0.9569566641435086

# %% [markdown]
# ### Regression code with SLR Assumptions

# %%
#Importing various modules required in the model creation and graphing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sb

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary.csv')
print (df.shape)
df.head()
# Out:
# (30, 2)
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#iloc for reading salary(dependent) and yearexperience(independent) variables into arrays
# Reading data into X and Y variables, if you notice X with iloc, you do not have to reshape the array
X=df.iloc[:,:-1].values
Y=df.iloc[:,1].values

'''
**********************************
Assumption 1 of Simple Linear Regression
1. The 2 variables X and Y need to be continous numeric, NOT categorical.
**********************************
'''
# By Inspecting the 2 variables X and Y, both are continous and Numeric
# Assumption 1 PASS

'''
**********************************
Assumption 2 of Simple Linear Regression
2. Data is free of Missing values, if missing values are there MVT(Missing Value Treatment) need to be performed.

**********************************
'''

def nmissing_counter(Y):
    if np.count_nonzero(~np.isnan(Y))==len(Y):
        print("No missing values")
    else:
        print("Missing value count is", len(Y)-np.count_nonzero(~np.isnan(Y)),"out of" , len(Y))
nmissing_counter(Y)
nmissing_counter(X)

# Assumption 2 PASS
# Out:
# No missing values
# No missing values

# %%
'''
**********************************
Assumption 3 of Simple Linear Regression
3. Data is free of outliers, 
If the  outliers are there take a business decision for removal @95% z=1.96 or @99.97% z=2.97

**********************************
'''
#np.abs is required as the z scores are negative as well, refer to z score
z = max(np.abs(stats.zscore(Y)))
print(z)

# Assumption 3 PASS
# Out:
# 1.72102849045861

# %%
'''
**********************************
Assumption 4 of Simple Linear Regression
4. Linear relationship between X and Y
**********************************
'''
x=df['YearsExperience'].values
y=df['Salary'].values
np.corrcoef(x,y)
df.cov()
sb.pairplot(df)
# Assumption 4 PASS as the relationship seems to be strongly linear and corr and cov are positive

# %%
'''
**********************************
Assumption/suggestion 5 of Simple Linear Regression
5. Depending on the case/business need, data should be split into TRAIN and TEST
**********************************
'''
# Assumption 5 PASS and we are splitting data, as per the problem
'''
***************************************************************************************
***************************************************************************************
***************************************************************************************
Carrying on with Simple Linear Regression
***************************************************************************************
***************************************************************************************
***************************************************************************************
'''
#splitting data into training and test sets
#Note that it would need 4 parameters in the same train and test sequence
#train_test_split is a function in the model_selection module
#X and Y are the arrays that we created above using iloc, always check the dimension
#test_size=1/3 so train_size=2/3, you can give either, usually 80 (Train):20(Test) is the norm
#random_state=0 is the seed value for replicating the results, we hardcode it for replicating the results
#The train and test would now have random values, this removes any data bias and let go of data inbuilt patterns
#The name could be any for the name of the sets a,b,c,d would work, just the sequence matters (train and test)

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=1/3,random_state=0)

# %%
#we import the LinearRegression class
#reg is simply a linear regressor object and LinearRegression is a class, reg is an instance of class 
#fit is a method available in LinearRegression class, this now creates a best line fit based on X and Y
#At this point the machine learning model is ready and the best fit line is in place
#this reg object can now be called with predict method for predicting value of an array or single value
#You cannot call the predict method if the object reg is not trained using the fit method
#Y_predict are the predicted salaries and Y_test are actuals, you can compare them to see the model's performance
#creating y_predict to match with Y_test, y_predict is created with X_test 
#In summary we are trying to predict y with test x and match against test y for the accuracy of the model
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,Y_train)
Y_predict=reg.predict(X_test)
Y_predict
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
#We are now trying to forecast, lets say what would be salary for 11 years of experince, for fun :) )
# predict is a method in LinearRegression class that helps in prediction based on trained model
#the trained model, the OLS best fitted line is with the reg object
#we are passing satic value of 11 years

Y_predict_val=reg.predict(np.array(5.5).reshape(1,1))
print(Y_predict_val)

#Implement the scatter line graph with X and Y train data
#Plotting the regression line with X and predicted Y on X train
#Basically creating line for X_train and predicted values from training data frame
# scatter is a function from plt
#in plt.plot the x is X_train and Y is predicted values of X_train or this is our y(hat), Y_train are the observed points

plt.scatter(X_train,Y_train,color='red',label="Scatter data")
plt.plot(X_train,reg.predict(X_train),c='green',label="Reg line")
#Giving title to the plot for making it look better, also giving labels to X and Y axis
plt.title('Salary and the Experience predictions for train data')
plt.xlabel('Years of Exp')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# [78218.8756812]

# %%
#Creating the plot for test data, very similar to the above graph
# we wish to keep the regression line as same, as this is the model line
plt.scatter(X_test,Y_test,color='red',label="Scatter data")
plt.plot(X_test,reg.predict(X_test),c='purple',label="Reg line")
#Giving title to the plot for making it look better, also giving labels to X and Y axis
plt.title('Salary and the Experience predictions for test data ')
plt.xlabel('Years of Exp')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
#Calculating the R square and printing it for the goodness of fit, it come out to be 93.8%
#The variation that can be explained by this model is 93.8%
#reg is the LinearRegression() object
r2_score=reg.score(X_train,Y_train)
print(r2_score)
# Out:
# 0.9381900012894278

# %%
#Let's calculate the RMSE from scartch, RMSE is also a measure of the goodness of fit of a model.
#The RMSE of $4585.41 is not bad and the model is predicting salaries to a good extent
rss=((Y_test-Y_predict)**2).sum() #residual sum of squares 
mse=np.mean((Y_test-Y_predict)**2) #mean square error
print(f"Final rmse value is :{np.sqrt(mse)}")
# Out:
# Final rmse value is :4585.4157204675885

# %% [markdown]
# ### Business sense New salary

# %% [markdown]
# The requirement has come from the HR to predict the salary of 10 potential candidates, the experience of these candidates is shared with you, being the Data scientist and using the previous trained model, please help in following.
#
# 1. Predict the salary of the 10 new potential hires.
# 2. How much sure you are about the model and what are your recommendadtions.
# 3. Leverage the earlier built model and we have extrapolated exp of 11 and 13 years as well.

# %%
#importing various modules and reading the new csv, new data there are 10 rows and extrapolated exp of 11 and 13 have come
#we just have X(exp) and need to predict the salaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_new=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary_new.csv')
df_new
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# 5              2.9
# 6              3.0
# 7              3.2
# 8             11.0
# 9             13.0

# %%
#using the iloc for create array, remember no need of reshaping it
X_test_new=df_new.iloc[:].values

#predicting new salary by using the earlier trained model
#remember the reg object should be alive in the session, you cannot have a brand new session and use below code.
# reg is storing the best fitted line OLS model and we can use the same for predicting salaries

Y_predict_sal_new=reg.predict(X_test_new)

print(X_test_new,Y_predict_sal_new)

#look for 11 yr exp sal is 129621 and 13 yrs it is 148313
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [11. ]
#  [13. ]] [ 37096.72893147  38965.91742009  40835.10590871  45508.07713028
#   47377.2656189   53919.42532909  54854.0195734   56723.20806202
#  129621.55911838 148313.44400462]

# %% [markdown]
# The 10 new potential hires have now joined the company, of course on different salaries. These salaries are not matching with what we have predicted.
#
# Requirement has come from the HR to predict the salary of 4 new potential candidates, the experience of these candidates is shared with you, being the Data scientist, revalidate and retrain the previous reg model with new data points, please help in following.
#
# 1. Predict the salary of the 4 new potential hires for iteration 2, the HR is demanding to adjust the model with new available data points.
# 2. Correct the model and revalidate it with new data and predict the salaries of new potential hires.
# 3. The new model should be trained on the 40 data points available(30 existing and 10 new hires)

# %%
#The most important scenario, we are now using reg_new model on salary_new
# We have got the new salary values of the hired employees and we have to now adjust the model as per new available data
#This is model corerction and model validation in light of new data points for adjusting the OLS best fit line
#Salary and salary_new_actuals would be used for training the model again for a better bit and smart model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary.csv')
df_actuals=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary_new_actuals.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df_actuals.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   37197
# 1              1.3   39966
# 2              1.5   41835
# 3              2.0   45608
# 4              2.2   48377

# %%
#Appending the 2 frames for making a new data frame.
#we would train model on this appended data, the model would now learn again and adjust itself for the new set
df_new2=pd.concat([df,df_actuals])
df_new2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Reading data into X and Y variables
X=df_new2.iloc[:,:-1].values
Y=df_new2.iloc[:,1].values

'''
#splitting data into training and test sets
# Do we really need to split the data? think :)
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)
'''
#Implement the reg object based on Simple Linear Regression
#Why are we fiiting and creating the model again, think :)
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,Y)

#Reading new salary data,(4 data points)for which we have to predict based on salary.csv and salary_new_actuals.csv
df_new_latest=pd.read_csv('https://raw.githubusercontent.com/Kash48/Salary_Prediction_Linear/master/salary_new2.csv')
X_test_latest=df_new_latest.iloc[:].values

#predicting new salary by using the earlier trained model
Y_predict_latest=reg.predict(X_test_latest)

#look for 11 yr exp sal was 129621 previously, however as per last model now it is 129613
#the model has adjusted itself to the new available data and now the sal is lowered down a bit :)
print(X_test_latest,Y_predict_latest)
# Out:
# [[11]
#  [13]
#  [15]
#  [17]] [129613.25715225 148360.52771273 167107.79827322 185855.0688337 ]
